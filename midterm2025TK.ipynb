# %% [markdown]
# <a href="https://colab.research.google.com/github/TKhahahah/dataviz2025/blob/main/midterm2025TK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %% [markdown]
# # ดึงข้อมูลแต่ละ file

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
crime_scene_report = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/crime_scene_report.csv')
crime_scene_report.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#           city
# 0          NYC
# 1       Albany
# 2         Reno
# 3  Pandas City
# 4  Pandas City

# %%
driver_lisence = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/drivers_license.csv')
driver_lisence.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
facebook = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/facebook_event_checkin.csv')
facebook.head()
# Out:
#    person_id  event_id                                         event_name  \
# 0      28508      5880    Nudists are people who wear one-button suits.\n
# 1      63713      3865  but that's because it's the best book on anyth...
# 2      63713      3999           If Murphy's Law can go wrong, it will.\n
# 3      63713      6436  Old programmers never die.  They just branch t...
# 4      82998      4470               Help a swallow land at Capistrano.\n
#
#        date
# 0  20170913
# 1  20171009
# 2  20170502
# 3  20170926
# 4  20171022

# %%
get_fit_check = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/get_fit_now_check_in.csv')
get_fit_check.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
get_fit_member = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/get_fit_now_member.csv')
get_fit_member.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
income = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/income.csv')
income.head()
# Out:
#          ssn  annual_income
# 0  100009868          52200
# 1  100169584          64500
# 2  100300433          74400
# 3  100355733          35900
# 4  100366269          73000

# %%
interview = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/interview.csv')
interview.head()
# Out:
#    person_id                                         transcript
# 0      28508                ‘I deny it!’ said the March Hare.\n
# 1      63713                                                 \n
# 2      86208      way, and the whole party swam to the shore.\n
# 3      35267  lessons in here? Why, there’s hardly room for ...
# 4      33856                                                 \n

# %%
person = pd.read_csv('/content/drive/MyDrive/Pythondataviz/Exam/person.csv')
person.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %% [markdown]
# # check info and clean

# %% [markdown]
# ## crime scene

# %%
crime_scene_report.shape
# Out:
# (1228, 4)

# %%
crime_scene_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1228 entries, 0 to 1227
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1228 non-null   int64
#  1   type         1228 non-null   object
#  2   description  1228 non-null   object
#  3   city         1228 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 38.5+ KB

# %%
crime_scene_report.isnull().any()
# Out:
# date           False
# type           False
# description    False
# city           False
# dtype: bool

# %% [markdown]
# ## driver license

# %%
driver_lisence.shape
driver_lisence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10007 entries, 0 to 10006
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10007 non-null  int64
#  1   age           10007 non-null  int64
#  2   height        10007 non-null  int64
#  3   eye_color     10007 non-null  object
#  4   hair_color    10007 non-null  object
#  5   gender        10007 non-null  object
#  6   plate_number  10007 non-null  object
#  7   car_make      10007 non-null  object
#  8   car_model     10007 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 703.7+ KB

# %%
driver_lisence.isnull()
# Out:
#           id    age  height  eye_color  hair_color  gender  plate_number  \
# 0      False  False   False      False       False   False         False
# 1      False  False   False      False       False   False         False
# 2      False  False   False      False       False   False         False
# 3      False  False   False      False       False   False         False
# 4      False  False   False      False       False   False         False
# ...      ...    ...     ...        ...         ...     ...           ...
# 10002  False  False   False      False       False   False         False
# 10003  False  False   False      False       False   False         False
# 10004  False  False   False      False       False   False         False
# 10005  False  False   False      False       False   False         False
# 10006  False  False   False      False       False   False         False
#
#        car_make  car_model
# 0         False      False
# 1         False      False
# ...

# %%
driver_lisence.isnull().any()
# Out:
# id              False
# age             False
# height          False
# eye_color       False
# hair_color      False
# gender          False
# plate_number    False
# car_make        False
# car_model       False
# dtype: bool

# %% [markdown]
# ## facebook

# %%
facebook.shape
# Out:
# (20011, 4)

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20011 entries, 0 to 20010
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   person_id   20011 non-null  int64
#  1   event_id    20011 non-null  int64
#  2   event_name  20011 non-null  object
#  3   date        20011 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 625.5+ KB

# %%
facebook.isnull()
# Out:
#        person_id  event_id  event_name   date
# 0          False     False       False  False
# 1          False     False       False  False
# 2          False     False       False  False
# 3          False     False       False  False
# 4          False     False       False  False
# ...          ...       ...         ...    ...
# 20006      False     False       False  False
# 20007      False     False       False  False
# 20008      False     False       False  False
# 20009      False     False       False  False
# 20010      False     False       False  False
#
# [20011 rows x 4 columns]

# %%
facebook.isnull().any()
# Out:
# person_id     False
# event_id      False
# event_name    False
# date          False
# dtype: bool

# %% [markdown]
# ## Get fir now check

# %%
get_fit_check.shape
# Out:
# (2703, 4)

# %%
get_fit_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2703 entries, 0 to 2702
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   membership_id   2703 non-null   object
#  1   check_in_date   2703 non-null   int64
#  2   check_in_time   2703 non-null   int64
#  3   check_out_time  2703 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 84.6+ KB

# %%
get_fit_check.isnull()
# Out:
#       membership_id  check_in_date  check_in_time  check_out_time
# 0             False          False          False           False
# 1             False          False          False           False
# 2             False          False          False           False
# 3             False          False          False           False
# 4             False          False          False           False
# ...             ...            ...            ...             ...
# 2698          False          False          False           False
# 2699          False          False          False           False
# 2700          False          False          False           False
# 2701          False          False          False           False
# 2702          False          False          False           False
#
# [2703 rows x 4 columns]

# %%
get_fit_check.isnull().any()
# Out:
# membership_id     False
# check_in_date     False
# check_in_time     False
# check_out_time    False
# dtype: bool

# %% [markdown]
# ## Get fit now member

# %%
get_fit_member.shape
# Out:
# (184, 5)

# %%
get_fit_member.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     184 non-null    object
#  1   person_id              184 non-null    int64
#  2   name                   184 non-null    object
#  3   membership_start_date  184 non-null    int64
#  4   membership_status      184 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 7.3+ KB

# %%
get_fit_member.isnull().any()
# Out:
# id                       False
# person_id                False
# name                     False
# membership_start_date    False
# membership_status        False
# dtype: bool

# %% [markdown]
# ## income

# %%
income.shape
# Out:
# (7514, 2)

# %%
income.isnull().any()
# Out:
# ssn              False
# annual_income    False
# dtype: bool

# %% [markdown]
# ## interview

# %%
interview.shape
# Out:
# (4991, 2)

# %%
interview.isnull().any()
# Out:
# person_id     False
# transcript    False
# dtype: bool

# %% [markdown]
# ## person

# %%
person.shape
# Out:
# (10011, 6)

# %%
person.isnull().any()
# Out:
# id                     False
# name                   False
# license_id             False
# address_number         False
# address_street_name    False
# ssn                    False
# dtype: bool

# %% [markdown]
# # หาพยาน

# %%
crime_scene_report[['date','type','city']]
# Out:
#           date     type          city
# 0     20180115  robbery           NYC
# 1     20180115   murder        Albany
# 2     20180115   murder          Reno
# 3     20180215   murder   Pandas City
# 4     20180215   murder   Pandas City
# ...        ...      ...           ...
# 1223  20180430  bribery  Garden Grove
# 1224  20180430    fraud         Houma
# 1225  20180430  assault       Fontana
# 1226  20180501  assault       Trenton
# 1227  20180115   murder   Pandas City
#
# [1228 rows x 3 columns]

# %%
murder_pandas_20180115 = crime_scene_report[
    (crime_scene_report['date'] == 20180115) &
    (crime_scene_report['type'] == 'murder') &
    (crime_scene_report['city'] == 'Pandas City')
]
display(murder_pandas_20180115)
# Out:
#           date    type  \
# 1227  20180115  murder
#
#                                                                                                                                                                                     description  \
# 1227  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#              city
# 1227  Pandas City

# %%
murder_pandas_20180115.shape
# Out:
# (1, 4)

# %%
pd.set_option('display.max_colwidth', None)
print(murder_pandas_20180115['description'])
# Out:
# 1227    Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# Name: description, dtype: object

# %% [markdown]
# ## second witness

# %%
second_witness = person[person['name'] == 'Annabel Miller']
display(second_witness)
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %% [markdown]
# ## first witness

# %%
witness_northwestern_all = person[person['address_street_name'] == 'Northwestern Dr']
display(witness_northwestern_all)
# Out:
#          id                  name  license_id  address_number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %%
max_address_num = witness_northwestern_all['address_number'].max()
print("เลขที่บ้านที่มากที่สุดบน Northwestern Dr คือ:", max_address_num)
# Out:
# เลขที่บ้านที่มากที่สุดบน Northwestern Dr คือ: 4919

# %%
witness_with_max_address = witness_northwestern_all[witness_northwestern_all['address_number'] == max_address_num]
display(witness_with_max_address)
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %% [markdown]
# first witness คือ Morty Schapiro
#
# Second witness คือ Annabel Miller

# %% [markdown]
# # หาตัวฆาตกร

# %%
witness_interviews = pd.merge(witness_northwestern_all, interview, left_on='id', right_on='person_id')
display(witness_interviews)
# Out:
#        id                  name  license_id  address_number  \
# 0   12711        Norman Apolito      667757             599
# 1   14887        Morty Schapiro      118009            4919
# 2   15171          Weldon Penso      336999             311
# 3   23960  Kristopher Lagerberg      658777            1392
# 4   25615         Olevia Morena      388477             812
# 5   26758      Angelena Billman      942074             629
# 6   28360        Rashad Cascone      924517            3212
# 7   34352    Vincenza Burkhardt      436470            2512
# 8   39688            Abe Roeker      537445             689
# 9   40336       Fredia Billeter      251082             404
# 10  51114     Christena Saffell      814284            3055
# 11  68690            Yer Modest      852404            3046
# 12  71924        Laurie Scronce      774116            1418
# 13  72076     Courtney Bordeaux      324614            1707
# 14  73368        Torie Thalmann      773862            3697
# ...

# %%
witness_interviews.shape
# Out:
# (20, 8)

# %%
witnesses_interviews_filtered = interview[interview['person_id'].isin([14887, 16371])]
display(witnesses_interviews_filtered)
# Out:
#       person_id  \
# 4988      14887
# 4989      16371
#
#                                                                                                                                                                                                                            transcript
# 4988  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# 4989                                                                                                            I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
gym_checkins_date_of_murder = get_fit_check[get_fit_check['check_in_date'] == 20180115]
display(gym_checkins_date_of_murder)
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 680          D2KY6       20180115            746             836
# 1553         344VM       20180115           1087            1195
# 2347         3BRSC       20180115            354             825
# 2649         HM6U8       20180115            525             800

# %%
potential_witnesses_gym = gym_checkins_date_of_murder[gym_checkins_date_of_murder['check_out_time'] < 1100]
display(potential_witnesses_gym)
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 680          D2KY6       20180115            746             836
# 2347         3BRSC       20180115            354             825
# 2649         HM6U8       20180115            525             800

# %%
potential_witness_details = pd.merge(potential_witnesses_gym, get_fit_member, left_on='membership_id', right_on='id')
potential_witness_details = pd.merge(potential_witness_details, person, left_on='person_id', right_on='id')
display(potential_witness_details)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time   id_x  \
# 0         D2KY6       20180115            746             836  D2KY6
# 1         3BRSC       20180115            354             825  3BRSC
# 2         HM6U8       20180115            525             800  HM6U8
#
#    person_id            name_x  membership_start_date membership_status  \
# 0      99602  Joline Hollering               20170220              gold
# 1      19948      Taylor Skyes               20180314              gold
# 2      50106       Edgar Bamba               20170128            silver
#
#     id_y            name_y  license_id  address_number address_street_name  \
# 0  99602  Joline Hollering      383435            3021           Celilo St
# 1  19948      Taylor Skyes      946454            2527             Flay St
# 2  50106       Edgar Bamba      438149             228      Marble Arch Rd
#
#          ssn
# 0  226217805
# 1  335326372
# 2  910274411

# %%
gold_members_48Z = get_fit_member[
    (get_fit_member['membership_status'] == 'gold') &
    (get_fit_member['id'].str.startswith('48Z'))
]
display(gold_members_48Z)
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
gym_checkins_jan_9 = get_fit_check[get_fit_check['check_in_date'] == 20180109]
display(gym_checkins_jan_9)
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 113          X0643       20180109            957            1164
# 889          UK1F2       20180109            344             518
# 1329         XTE42       20180109            486            1124
# 1446         1AE2H       20180109            461             944
# 1703         6LSTG       20180109            399             515
# 2137         7MWHJ       20180109            273             885
# 2435         GE5Q8       20180109            367             959
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700

# %% [markdown]
# membership_id 48Z7A และ 48Z55 เข้าใช้วันที่ 20190109 ที่ถูกเห็นโดย Annabel Miller

# %%
person_with_license = pd.merge(person, driver_lisence, left_on='license_id', right_on='id')
display(person_with_license)
# Out:
#         id_x                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10001  99936          Luba Benser      274427             680
# 10002  99941      Roxana Mckimley      975942            1613
# 10003  99965      Cherie Zeimantz      287627            3661
# 10004  99982          Allen Cruse      251350            3126
# 10005  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn    id_y  age  height eye_color  \
# 0            Bankhall Ave  747714076  993845   46      59     black
# 1           Gustavus Blvd  477972044  861794   54      74     black
# ...

# %%
check_H42W = person_with_license[
    (person_with_license['plate_number'].str.contains('H42W')) &
    (person_with_license['name'].isin(['Joe Germuska', 'Jeremy Bowers']))
]
display(check_H42W)
# Out:
#        id_x           name  license_id  address_number    address_street_name  \
# 6323  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn    id_y  age  height eye_color hair_color gender plate_number  \
# 6323  871539279  423327   30      70     brown      brown   male       0H42W2
#
#        car_make car_model
# 6323  Chevrolet  Spark LS

# %% [markdown]
# # หาตัวผู้บงการ

# %%
jeremy_bowers_interview = interview[interview['person_id'] == 67318]
display(jeremy_bowers_interview)
# Out:
#       person_id  \
# 4990      67318
#
#                                                                                                                                                                                                                                               transcript
# 4990  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %%
find_woman = driver_lisence[(driver_lisence['gender'] == 'female') & (driver_lisence['car_make'] == 'Tesla') & (driver_lisence['car_model'] == 'Model S') & (driver_lisence['hair_color'] == 'red')]
display(find_woman)
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %%
hight_woman = find_woman[(find_woman['height'] >= 65) & (find_woman['height'] <= 67)]
display(hight_woman)
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %%
find_names = person_with_license[person_with_license['id_y'].isin([202298, 291182, 918773])]
display(find_names[['name', 'id_y', 'id_x']])
# Out:
#                   name    id_y   id_x
# 7660          Red Korb  918773  78881
# 8972     Regina George  291182  90700
# 9980  Miranda Priestly  202298  99716

# %%
mastermind = find_names[find_names['id_x'].isin(attended_3_times['person_id'])]
display(mastermind)
# Out:
#        id_x              name  license_id  address_number address_street_name  \
# 9980  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn    id_y  age  height eye_color hair_color  gender  \
# 9980  987756388  202298   68      66     green        red  female
#
#      plate_number car_make car_model
# 9980       500123    Tesla   Model S

# %% [markdown]
# # คำตอบ

# %% [markdown]
# ดังนั้น ตัวฆาตกร คือ Jeremy Bowers
# และผู้บงการ คือ Miranda Priestly
